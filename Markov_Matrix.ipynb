# %%
import processviz as pvz

# %%
G = pvz.MarkovChain()
G.from_file()

# %%
G.generate_graph(3)

# %%
G.generate_state_graph(3)

# %%
G.state_vector
# Out:
# array([0.0752, 0.3605, 0.5643])

# %%
print(G.is_connected(0, 0))
# Out:
# None
